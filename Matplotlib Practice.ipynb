# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(100,4), columns=["A","B","C","D"], index = pd.date_range('2022-05-25', periods=100))
df
# Out:
#                    A         B         C         D
# 2022-05-25 -0.869705  1.084025  0.324501  0.598875
# 2022-05-26 -0.596385  0.943434  0.068599  0.241547
# 2022-05-27 -0.267425  1.973479 -1.065917  1.355570
# 2022-05-28  1.836520 -0.300414  0.667846 -0.178114
# 2022-05-29  0.504675 -0.792312  0.037658 -0.614949
# ...              ...       ...       ...       ...
# 2022-08-28  2.134393  0.169059 -0.311067  2.853450
# 2022-08-29 -0.916685  0.463469  0.597397 -0.173310
# 2022-08-30 -1.058536  0.600889  0.078796  1.404051
# 2022-08-31 -0.680225  0.997394  1.476265 -0.530446
# 2022-09-01 -0.670351 -0.333135 -0.069529  0.116830
#
# [100 rows x 4 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#Iris Dataset

df_1 = pd.read_csv("https://gist.githubusercontent.com/0663925298/b60b4153bc6acc1f256803110cdf04a3/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")

# %%
df_1.iplot()
# Out:
# <div>                            <div id="b481dace-07f9-498d-8c52-858b9b3c9b1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df_1.iloc[5:11].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df_1.plot(kind='hist',bins=20, figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_1['sepal_length'].plot(kind='hist',bins=10, orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df_1.hist(figsize = (20,10), color='r', alpha=0.5)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df_1.boxplot(figsize=(20,10), color = {'boxes':'g', 'whiskers':'r'})
# Out:
# <AxesSubplot:>

# %%
df_1.plot(kind='area',figsize=(20,10), alpha= 0.3, stacked= False)
# Out:
# <AxesSubplot:>

# %%
df_1.plot(kind='area',figsize=(20,10), alpha= 0.3, stacked= True)
# Out:
# <AxesSubplot:>

# %%
df_1.plot.scatter(x='sepal_length', y='sepal_width', figsize=(10,5), c='petal_length', s=100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df_1.plot.hexbin(x='sepal_length', y='petal_length', figsize=(20,10), gridsize=15, C='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
dff = df_1.drop(columns='species').iloc[0]
dff
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
dff.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_1.iplot(kind='scatter', x='sepal_length', y='sepal_width', mode='markers')
# Out:
# <div>                            <div id="a223fcc5-94c8-4f3b-b09d-e60c2f20a073" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df_1.iplot(kind='scatter', mode='markers', size=10)
# Out:
# <div>                            <div id="d5d0be6f-2e99-4e37-b04c-599bcfb2d309" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df_1.scatter_matrix()
# Out:
# <div>                            <div id="a0815778-73dd-41cf-824a-a99aae52bddf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df_1.iplot(kind='scatter3d',x='sepal_length', y='sepal_width', z='petal_length')
# Out:
# <div>                            <div id="1a687836-b697-4116-b8e1-2a77979cf284" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
